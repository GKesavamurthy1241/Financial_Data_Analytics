# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

# %%
old_df = pd.read_csv('Financial Analytics data.csv')
old_df.head()
# Out:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51

# %%
old_df.isna().sum()
# Out:
# S.No.                 0
# Name                  0
# Mar Cap - Crore       9
# Sales Qtr - Crore    29
# dtype: int64

# %%
old_df.shape
# Out:
# (488, 4)

# %%
df = old_df.dropna()

# %%
# Display basic information about the dataset
print(df.info())

# Display basic statistics of numerical columns
print(df.describe())
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 459 entries, 0 to 486
# Data columns (total 4 columns):
#  #   Column             Non-Null Count  Dtype
# ---  ------             --------------  -----
#  0   S.No.              459 non-null    int64
#  1   Name               459 non-null    object
#  2   Mar Cap - Crore    459 non-null    float64
#  3   Sales Qtr - Crore  459 non-null    float64
# dtypes: float64(2), int64(1), object(1)
# memory usage: 17.9+ KB
# None
#             S.No.  Mar Cap - Crore  Sales Qtr - Crore
# count  459.000000       459.000000         459.000000
# mean   246.575163     28870.974139        3807.789412
# std    146.046444     60557.081792        9989.449987
# min      1.000000      3017.070000           0.000000
# 25%    117.500000      4942.815000         534.910000
# 50%    243.000000     10442.090000        1137.170000
# 75%    371.500000     24707.320000        2730.195000
# max    499.000000    583436.720000      110666.930000

# %%
# Calculate mean market capitalization and mean quarterly sales
mean_mar_cap = df['Mar Cap - Crore'].mean()
mean_sales_qtr = df['Sales Qtr - Crore'].mean()

print(f"Mean Market Capitalization: {mean_mar_cap}")
print(f"Mean Quarterly Sales: {mean_sales_qtr}")
# Out:
# Mean Market Capitalization: 28870.974139433554
# Mean Quarterly Sales: 3807.789411764706

# %%
# Select only numeric columns for correlation
numeric_df = df.select_dtypes(include=[float, int])

# Compute the correlation matrix
correlation_matrix = numeric_df.corr()

# Plot the heatmap
plt.figure(figsize=(10, 8))
sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
plt.title('Correlation Matrix')
plt.show()

# %%
# Top companies based on market capitalization
top_market_cap_companies = df.nlargest(10, 'Mar Cap - Crore')
print("Top 10 Companies by Market Cap:")
print(top_market_cap_companies)
# Out:
# Top 10 Companies by Market Cap:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51
# 5      6  Hind. Unilever        288265.26            8590.00
# 6      7   Maruti Suzuki        263493.81           19283.20
# 7      8         Infosys        248320.35           17794.00
# 8      9         O N G C        239981.50           22995.88
# 9     10  St Bk of India        232763.33           57014.08

# %%
# Correlation between market capitalization and quarterly sales
correlation_market_cap_sales = df['Mar Cap - Crore'].corr(df['Sales Qtr - Crore'])
print(f"Correlation between Market Cap and Sales: {correlation_market_cap_sales}")
# Out:
# Correlation between Market Cap and Sales: 0.624409142298052

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import seaborn as sns

def load_data(file_path):
    """Load data from a CSV file and return the DataFrame."""
    df = pd.read_csv(file_path)
    return df

def handle_missing_values(data_frame):
    """Drop rows with missing values and return the cleaned DataFrame."""
    cleaned_df = data_frame.dropna()
    return cleaned_df

def calculate_mean_metrics(data_frame):
    """Calculate mean market capitalization and mean quarterly sales."""
    mean_mar_cap = data_frame['Mar Cap - Crore'].mean()
    mean_sales_qtr = data_frame['Sales Qtr - Crore'].mean()

    print(f"Mean Market Capitalization: {mean_mar_cap}")
    print(f"Mean Quarterly Sales: {mean_sales_qtr}")

def create_scatter_plot(data_frame):
    """Create a scatter plot of market capitalization vs. quarterly sales."""
    sns.scatterplot(x='Mar Cap - Crore', y='Sales Qtr - Crore', data=data_frame)
    plt.title('Market Cap vs. Quarterly Sales')
    plt.show()

def create_correlation_matrix(data_frame):
    """Create a correlation matrix plot."""
    numeric_df = data_frame.select_dtypes(include=[float, int])
    correlation_matrix = numeric_df.corr()
    plt.figure(figsize=(10, 8))
    sns.heatmap(correlation_matrix, annot=True, cmap='coolwarm')
    plt.title('Correlation Matrix')
    plt.show()

def top_market_cap_companies(data_frame, n=10):
    """Print the top N companies based on market capitalization."""
    top_companies = data_frame.nlargest(n, 'Mar Cap - Crore')
    print(f"Top {n} Companies by Market Cap:")
    print(top_companies)

def calculate_correlation(data_frame):
    """Calculate and print the correlation between market capitalization and quarterly sales."""
    correlation_market_cap_sales = data_frame['Mar Cap - Crore'].corr(data_frame['Sales Qtr - Crore'])
    print(f"Correlation between Market Cap and Sales: {correlation_market_cap_sales}")

if __name__ == "__main__":
    # Load data
    file_path = 'Financial Analytics data.csv'
    old_df = load_data(file_path)

    # Display basic information about the original dataset
    print("Original DataFrame:")
    print(old_df.head())

    # Handle missing values and continue with the cleaned DataFrame
    df = handle_missing_values(old_df)

    # Calculate mean metrics
    calculate_mean_metrics(df)

    # Create scatter plot
    create_scatter_plot(df)

    # Create correlation matrix plot
    create_correlation_matrix(df)

    # Display top companies based on market capitalization
    top_market_cap_companies(df)

    # Calculate and display correlation between market capitalization and quarterly sales
    calculate_correlation(df)
# Out:
# Original DataFrame:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51
# Mean Market Capitalization: 28870.974139433554
# Mean Quarterly Sales: 3807.789411764706
# Top 10 Companies by Market Cap:
#    S.No.            Name  Mar Cap - Crore  Sales Qtr - Crore
# 0      1  Reliance Inds.        583436.72           99810.00
# 1      2             TCS        563709.84           30904.00
# 2      3       HDFC Bank        482953.59           20581.27
# 3      4             ITC        320985.27            9772.02
# 4      5         H D F C        289497.37           16840.51
# 5      6  Hind. Unilever        288265.26            8590.00
# ...
